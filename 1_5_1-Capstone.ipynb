# %% [markdown]
# ## Unit 1 Capstone: A/B Experiment
#
# Over the course of my Thinkful curriculum, it is my goal to apply predictive analytics to my client's [Customer Relationship Management](https://en.wikipedia.org/wiki/Customer_relationship_management) (or "CRM") database.
#
# It's my overall hypothesis that predective analytics will be a better predictor that HubSpot's standard "Likeliness to Close" rating.
#
# This experiment, in accordance to Thinkful's Unit 1 Capstone, will explore my client's CRM database and run an A/B experiment on two variables from one of its datatables.

# %% [markdown]
# ### Import Packages and Resize Charts

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats

# %%
# Resize charts via seaborn
plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams.update({'font.size': 22})

# %% [markdown]
# ### Create function(s)

# %%
def WinsorizeCustom(data):
    quantiles = data.quantile([0.1, 0.9])
    q_05 = quantiles.loc[0.1]
    q_95 = quantiles.loc[0.9]

    out = np.where(data.values <= q_05,q_05, 
                                      np.where(data >= q_95, q_95, data)
                  )
    return out

# %% [markdown]
# ### Import data

# %% [markdown]
# #### Deals

# %%
hs_deals = 'hs_deals-2018_08_14.csv'
df_deals_raw = pd.read_csv(hs_deals)

# %%
df_deals_raw.info(max_cols=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Columns: 98 entries, Company ID to Parent Company
# dtypes: float64(30), int64(1), object(67)
# memory usage: 117.2+ KB

# %% [markdown]
# Deals, leads that have turned into accounts (customers), only have 153 entries, which is not enough data to run an experiment on. This data will prove useful later on when analyzing the attritubes of the accounts that can be applied to our lead datatables.

# %% [markdown]
# #### Companies (or Leads)

# %%
hs_companies = 'hs_companies-2018_09_29.csv'
df_companies_raw = pd.read_csv(hs_companies)

# %%
df_companies_raw.info(max_cols=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6805 entries, 0 to 6804
# Columns: 99 entries, Company ID to Parent Company
# dtypes: float64(26), int64(1), object(72)
# memory usage: 5.1+ MB

# %% [markdown]
# Companies, are leads before then become accounts. Initially, I thought this would be the only other dataset needed to be used for my predictive analytics capstone.
#
# Unfortunately, after speaking with my client's VP of Marketing, this dataset is incomplete and needs to be combined with the last dataset, contacts. An indicator of incompleteness is the 'Lifecycle Stage', an automatically generated variable, only has 577 entries, which is less than 10% of the total records of the dataset.

# %% [markdown]
# #### Contacts

# %%
hs_contacts = 'hs_contacts-2018_09_29.csv'
df_contacts_raw = pd.read_csv(hs_contacts)
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (9,15,18,29,32,37,44,47,63,67,69,70,71,76,93,112,118,147,157,164,187,188,195) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_contacts_raw.info(max_cols=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11450 entries, 0 to 11449
# Columns: 209 entries, Contact ID to Associated Company
# dtypes: float64(69), int64(2), object(138)
# memory usage: 18.3+ MB

# %% [markdown]
# Contacts are the individuals of the companies that our sales team builds relationships with during the sales process.
#
# While it's more complete than the companies dataset, this data could use some cleaning, as it's much larger than the other datasets.

# %% [markdown]
# ### Clean Contacts Dataset

# %%
#Limit df to rows with entries for Website URL
df_contacts = df_contacts_raw.dropna(axis='index', subset=['Company Name'])

# %%
#Limit df to columns with at least 150 entries
df_contacts = df_contacts.dropna(axis='columns',thresh=150)

# %%
# Use RegEx to drop columns w/ specific strings
df_contacts = df_contacts[df_contacts.columns.drop(list(df_contacts.filter(regex='IP ')))]
df_contacts = df_contacts[df_contacts.columns.drop(list(df_contacts.filter(regex='Phone')))]
df_contacts = df_contacts[df_contacts.columns.drop(list(df_contacts.filter(regex='Sticky')))]
df_contacts = df_contacts[df_contacts.columns.drop(list(df_contacts.filter(regex='Google')))]
df_contacts = df_contacts[df_contacts.columns.drop(list(df_contacts.filter(regex='Salesforce')))]

# %%
# Drop specific columns
df_contacts = df_contacts[df_contacts.columns.drop([
    'Notes', 'Street Address', 'Trade Show Name', 'City', 'Twitter Username'
])]

# %%
# Creates new, continuous variable columns for categorical variables
contact_dummy = pd.get_dummies(df_contacts['Lifecycle Stage'])

# %%
# View variables
df_contacts.info(max_cols=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10417 entries, 0 to 11449
# Columns: 110 entries, Contact ID to Associated Company
# dtypes: float64(26), int64(2), object(82)
# memory usage: 8.8+ MB

# %% [markdown]
# After reducing the number of columns and dropping some null values, the size of the dataset has been more than halved.
#
# There is also enough data here to run an A/B test for my Unit 1 capstone.

# %% [markdown]
# ### A/B Experiment

# %%
sns.countplot(x='Source', data=df_contacts)
plt.xticks(rotation=90);

# %% [markdown]
# The purpose of this experiment is to test when one source of leads is better than another, according to the "Likelihood to Close" metric. This metric, generated by HubSpot, is a rating that ranges from 0 - 100 probability that a lead will close within the next 90 days.
#
# Our VP of Marketing suspects that this is in part driven by the source of the lead. An AB test of 'BDR' and 'List Build' should provide a reliable indicator on whether the source of a lead is driving the rating.
#
# My **hypothesis** is that the *higher rate for BDR source* is not by chance, in comparison to the *List Build source rating*.

# %% [markdown]
# ### The Experiment

# %%
sns.barplot(x='Source', y='Likelihood to close', data=df_contacts)
plt.xticks(rotation=90);
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Create sample data.
bdr = df_contacts['Likelihood to close'][df_contacts.Source == 'BDR'].dropna()
list_build = df_contacts['Likelihood to close'][df_contacts.Source == 'List Build'].dropna()

# Use scipy.stats.ttest_ind.
t, p = stats.ttest_ind(bdr, list_build, equal_var=False)
print("ttest_ind:            t = %g  p = %g" % (t, p))
# Out:
# ttest_ind:            t = 3.67223  p = 0.000252382

# %% [markdown]
# As expected, my **hypothesis is correct**. A t value of nearly 4 indicates a massive difference between the two variables and an extremely low p value of 0.00025 makes it nearly statistically impossible that this an occurance of chance.

# %% [markdown]
# ### Additional Analysis and Visualizations

# %%
# Create rating array and drop null values
rating = np.array(df_contacts['Likelihood to close'].dropna())

# %%
rating_winsor = WinsorizeCustom(df_contacts['Likelihood to close'].dropna())

# %%
sns.distplot(rating_winsor, rug = True)
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_contacts.corr()
# Out:
#                                   Contact ID  Broadcast Clicks  \
# Contact ID                          1.000000          0.016457
# Broadcast Clicks                    0.016457          1.000000
# Marketing emails opened             0.487042         -0.011709
# Total Revenue                      -0.001467         -0.031569
# Klout Score                        -0.112696               NaN
# Number of Pageviews                -0.003371          0.020670
# Facebook Clicks                    -0.006218          0.137854
# Associated Deals                   -0.068090         -0.006832
# Recent Deal Amount                  0.005374         -0.029081
# Number of times contacted          -0.067096          0.027610
# Number of Sales Activities         -0.120082          0.031517
# Number of Form Submissions          0.041089          0.029099
# Number of event completions              NaN               NaN
# Average Pageviews                   0.049768          0.050205
# Marketing emails delivered          0.696709         -0.008277
# Number of Unique Forms Submitted    0.060026          0.058876
# Number of Visits                   -0.000031          0.021206
# LinkedIn Clicks                     0.013625          0.898275
# Event Revenue                            NaN               NaN
# Marketing emails clicked            0.176609         -0.015587
# Follower Count                     -0.005691               NaN
# Associated Company ID               0.840322         -0.012929
# Twitter Clicks                      0.008267          0.436359
# Likelihood to close                 0.230968          0.110359
# LinkedIn Connections                0.090362               NaN
# Sends Since Last Engagement         0.467618         -0.013303
# Days To Close                      -0.790355         -0.020972
# Marketing emails bounced            0.168144               NaN
#
#                                   Marketing emails opened  Total Revenue  \
# Contact ID                                       0.487042      -0.001467
# Broadcast Clicks                                -0.011709      -0.031569
# Marketing emails opened                          1.000000      -0.051766
# Total Revenue                                   -0.051766       1.000000
# Klout Score                                      0.159446      -0.653008
# Number of Pageviews                             -0.009402      -0.049131
# Facebook Clicks                                 -0.011709            NaN
# Associated Deals                                -0.013077       0.101335
# Recent Deal Amount                              -0.050134       0.977681
# Number of times contacted                       -0.045711       0.198592
# Number of Sales Activities                      -0.072659       0.195383
# Number of Form Submissions                      -0.106632      -0.087782
# Number of event completions                           NaN            NaN
# Average Pageviews                               -0.074361      -0.039190
# Marketing emails delivered                       0.615040      -0.041135
# Number of Unique Forms Submitted                -0.116803      -0.099059
# Number of Visits                                 0.007577      -0.074808
# LinkedIn Clicks                                       NaN      -0.031569
# Event Revenue                                         NaN            NaN
# Marketing emails clicked                         0.255613            NaN
# Follower Count                                  -0.003166      -0.525631
# Associated Company ID                            0.456661       0.013502
# Twitter Clicks                                  -0.011709            NaN
# Likelihood to close                             -0.007722            NaN
# LinkedIn Connections                                  NaN            NaN
# Sends Since Last Engagement                     -0.115973       0.121102
# Days To Close                                   -0.003762       0.137515
# Marketing emails bounced                              NaN            NaN
#
#                                   Klout Score  Number of Pageviews  \
# Contact ID                          -0.112696            -0.003371
# Broadcast Clicks                          NaN             0.020670
# Marketing emails opened              0.159446            -0.009402
# Total Revenue                       -0.653008            -0.049131
# Klout Score                          1.000000            -0.074648
# Number of Pageviews                 -0.074648             1.000000
# Facebook Clicks                           NaN             0.252449
# Associated Deals                          NaN            -0.017199
# Recent Deal Amount                  -0.653008            -0.043984
# Number of times contacted           -0.050620             0.093263
# Number of Sales Activities          -0.069485             0.108827
# Number of Form Submissions          -0.113454             0.259318
# Number of event completions               NaN                  NaN
# Average Pageviews                   -0.049643             0.182342
# Marketing emails delivered          -0.009898            -0.018010
# Number of Unique Forms Submitted    -0.122266             0.220241
# Number of Visits                    -0.087092             0.957230
# LinkedIn Clicks                           NaN             0.015588
# Event Revenue                             NaN                  NaN
# Marketing emails clicked                  NaN             0.173731
# Follower Count                       0.406152            -0.011105
# Associated Company ID               -0.120367            -0.003626
# Twitter Clicks                            NaN             0.007854
# Likelihood to close                 -0.030475             0.141813
# LinkedIn Connections                -0.136346            -0.003468
# Sends Since Last Engagement          0.018237            -0.029944
# Days To Close                       -0.030345            -0.035615
# Marketing emails bounced                  NaN            -0.012648
#
#                                   Facebook Clicks  Associated Deals  \
# Contact ID                              -0.006218         -0.068090
# Broadcast Clicks                         0.137854         -0.006832
# Marketing emails opened                 -0.011709         -0.013077
# Total Revenue                                 NaN          0.101335
# Klout Score                                   NaN               NaN
# Number of Pageviews                      0.252449         -0.017199
# Facebook Clicks                          1.000000               NaN
# Associated Deals                              NaN          1.000000
# Recent Deal Amount                            NaN         -0.060225
# Number of times contacted               -0.008381          0.195762
# Number of Sales Activities              -0.008908          0.213729
# Number of Form Submissions               0.243376         -0.080979
# Number of event completions                   NaN               NaN
# Average Pageviews                        0.043788         -0.076554
# Marketing emails delivered              -0.008277          0.000000
# Number of Unique Forms Submitted         0.308160         -0.085367
# Number of Visits                         0.281089         -0.025175
# LinkedIn Clicks                         -0.000142         -0.006832
# Event Revenue                                 NaN               NaN
# Marketing emails clicked                -0.015587               NaN
# Follower Count                                NaN               NaN
# Associated Company ID                   -0.008965         -0.050052
# Twitter Clicks                           0.316146               NaN
# Likelihood to close                      0.022113               NaN
# LinkedIn Connections                          NaN               NaN
# Sends Since Last Engagement             -0.013871          0.031814
# Days To Close                                 NaN          0.035807
# Marketing emails bounced                      NaN               NaN
#
#                                   Recent Deal Amount  \
# Contact ID                                  0.005374
# Broadcast Clicks                           -0.029081
# Marketing emails opened                    -0.050134
# Total Revenue                               0.977681
# Klout Score                                -0.653008
# Number of Pageviews                        -0.043984
# Facebook Clicks                                  NaN
# Associated Deals                           -0.060225
# Recent Deal Amount                          1.000000
# Number of times contacted                   0.180727
# Number of Sales Activities                  0.172682
# Number of Form Submissions                 -0.070145
# Number of event completions                      NaN
# Average Pageviews                          -0.023434
# Marketing emails delivered                 -0.036829
# Number of Unique Forms Submitted           -0.080169
# Number of Visits                           -0.067635
# LinkedIn Clicks                            -0.029081
# Event Revenue                                    NaN
# Marketing emails clicked                         NaN
# Follower Count                             -0.525631
# Associated Company ID                       0.014111
# Twitter Clicks                                   NaN
# Likelihood to close                              NaN
# LinkedIn Connections                             NaN
# Sends Since Last Engagement                 0.104323
# Days To Close                               0.140889
# Marketing emails bounced                         NaN
#
#                                   Number of times contacted  \
# Contact ID                                        -0.067096
# Broadcast Clicks                                   0.027610
# Marketing emails opened                           -0.045711
# Total Revenue                                      0.198592
# Klout Score                                       -0.050620
# Number of Pageviews                                0.093263
# Facebook Clicks                                   -0.008381
# Associated Deals                                   0.195762
# Recent Deal Amount                                 0.180727
# Number of times contacted                          1.000000
# Number of Sales Activities                         0.949342
# Number of Form Submissions                         0.096203
# Number of event completions                             NaN
# Average Pageviews                                  0.163305
# Marketing emails delivered                         0.002804
# Number of Unique Forms Submitted                   0.204584
# Number of Visits                                   0.098187
# LinkedIn Clicks                                    0.035040
# Event Revenue                                           NaN
# Marketing emails clicked                           0.039024
# Follower Count                                    -0.014223
# Associated Company ID                             -0.042995
# Twitter Clicks                                    -0.008381
# Likelihood to close                                0.137749
# LinkedIn Connections                               0.016314
# Sends Since Last Engagement                       -0.034380
# Days To Close                                     -0.126122
# Marketing emails bounced                           0.101079
#
#                                             ...             Event Revenue  \
# Contact ID                                  ...                       NaN
# Broadcast Clicks                            ...                       NaN
# Marketing emails opened                     ...                       NaN
# Total Revenue                               ...                       NaN
# Klout Score                                 ...                       NaN
# Number of Pageviews                         ...                       NaN
# Facebook Clicks                             ...                       NaN
# Associated Deals                            ...                       NaN
# Recent Deal Amount                          ...                       NaN
# Number of times contacted                   ...                       NaN
# Number of Sales Activities                  ...                       NaN
# Number of Form Submissions                  ...                       NaN
# Number of event completions                 ...                       NaN
# Average Pageviews                           ...                       NaN
# Marketing emails delivered                  ...                       NaN
# Number of Unique Forms Submitted            ...                       NaN
# Number of Visits                            ...                       NaN
# LinkedIn Clicks                             ...                       NaN
# Event Revenue                               ...                       NaN
# Marketing emails clicked                    ...                       NaN
# Follower Count                              ...                       NaN
# Associated Company ID                       ...                       NaN
# Twitter Clicks                              ...                       NaN
# Likelihood to close                         ...                       NaN
# LinkedIn Connections                        ...                       NaN
# Sends Since Last Engagement                 ...                       NaN
# Days To Close                               ...                       NaN
# Marketing emails bounced                    ...                       NaN
#
#                                   Marketing emails clicked  Follower Count  \
# Contact ID                                        0.176609       -0.005691
# Broadcast Clicks                                 -0.015587             NaN
# Marketing emails opened                           0.255613       -0.003166
# Total Revenue                                          NaN       -0.525631
# Klout Score                                            NaN        0.406152
# Number of Pageviews                               0.173731       -0.011105
# Facebook Clicks                                  -0.015587             NaN
# Associated Deals                                       NaN             NaN
# Recent Deal Amount                                     NaN       -0.525631
# Number of times contacted                         0.039024       -0.014223
# Number of Sales Activities                        0.074667       -0.029077
# Number of Form Submissions                        0.135937       -0.023669
# Number of event completions                            NaN             NaN
# Average Pageviews                                 0.090773       -0.021062
# Marketing emails delivered                        0.228743        0.005905
# Number of Unique Forms Submitted                  0.078421       -0.024670
# Number of Visits                                  0.061809       -0.010338
# LinkedIn Clicks                                        NaN             NaN
# Event Revenue                                          NaN             NaN
# Marketing emails clicked                          1.000000             NaN
# Follower Count                                         NaN        1.000000
# Associated Company ID                             0.128021        0.001519
# Twitter Clicks                                   -0.015587             NaN
# Likelihood to close                               0.165073       -0.037718
# LinkedIn Connections                                   NaN       -0.019496
# Sends Since Last Engagement                      -0.033079       -0.024051
# Days To Close                                    -0.189976        0.115001
# Marketing emails bounced                               NaN             NaN
#
#                                   Associated Company ID  Twitter Clicks  \
# Contact ID                                     0.840322        0.008267
# Broadcast Clicks                              -0.012929        0.436359
# Marketing emails opened                        0.456661       -0.011709
# Total Revenue                                  0.013502             NaN
# Klout Score                                   -0.120367             NaN
# Number of Pageviews                           -0.003626        0.007854
# Facebook Clicks                               -0.008965        0.316146
# Associated Deals                              -0.050052             NaN
# Recent Deal Amount                             0.014111             NaN
# Number of times contacted                     -0.042995       -0.008381
# Number of Sales Activities                    -0.103619       -0.008908
# Number of Form Submissions                     0.030891        0.014531
# Number of event completions                         NaN             NaN
# Average Pageviews                              0.063079        0.027258
# Marketing emails delivered                     0.650140       -0.008277
# Number of Unique Forms Submitted               0.077892        0.029477
# Number of Visits                              -0.001197        0.013388
# LinkedIn Clicks                               -0.009385       -0.000112
# Event Revenue                                       NaN             NaN
# Marketing emails clicked                       0.128021       -0.015587
# Follower Count                                 0.001519             NaN
# Associated Company ID                          1.000000       -0.012178
# Twitter Clicks                                -0.012178        1.000000
# Likelihood to close                            0.153861        0.027931
# LinkedIn Connections                          -0.028523             NaN
# Sends Since Last Engagement                    0.436277       -0.013871
# Days To Close                                 -0.292273             NaN
# Marketing emails bounced                       0.169879             NaN
#
#                                   Likelihood to close  LinkedIn Connections  \
# Contact ID                                   0.230968              0.090362
# Broadcast Clicks                             0.110359                   NaN
# Marketing emails opened                     -0.007722                   NaN
# Total Revenue                                     NaN                   NaN
# Klout Score                                 -0.030475             -0.136346
# Number of Pageviews                          0.141813             -0.003468
# Facebook Clicks                              0.022113                   NaN
# Associated Deals                                  NaN                   NaN
# Recent Deal Amount                                NaN                   NaN
# Number of times contacted                    0.137749              0.016314
# Number of Sales Activities                   0.166325             -0.008108
# Number of Form Submissions                   0.188315             -0.008291
# Number of event completions                       NaN                   NaN
# Average Pageviews                            0.196894             -0.010106
# Marketing emails delivered                  -0.041874              0.216102
# Number of Unique Forms Submitted             0.284309             -0.008291
# Number of Visits                             0.151727             -0.004267
# LinkedIn Clicks                              0.190897                   NaN
# Event Revenue                                     NaN                   NaN
# Marketing emails clicked                     0.165073                   NaN
# Follower Count                              -0.037718             -0.019496
# Associated Company ID                        0.153861             -0.028523
# Twitter Clicks                               0.027931                   NaN
# Likelihood to close                          1.000000             -0.009350
# LinkedIn Connections                        -0.009350              1.000000
# Sends Since Last Engagement                 -0.075436              0.193656
# Days To Close                                     NaN                   NaN
# Marketing emails bounced                    -0.072175                   NaN
#
#                                   Sends Since Last Engagement  Days To Close  \
# Contact ID                                           0.467618      -0.790355
# Broadcast Clicks                                    -0.013303      -0.020972
# Marketing emails opened                             -0.115973      -0.003762
# Total Revenue                                        0.121102       0.137515
# Klout Score                                          0.018237      -0.030345
# Number of Pageviews                                 -0.029944      -0.035615
# Facebook Clicks                                     -0.013871            NaN
# Associated Deals                                     0.031814       0.035807
# Recent Deal Amount                                   0.104323       0.140889
# Number of times contacted                           -0.034380      -0.126122
# Number of Sales Activities                          -0.061879      -0.136404
# Number of Form Submissions                          -0.109099      -0.064097
# Number of event completions                               NaN            NaN
# Average Pageviews                                   -0.118154      -0.055921
# Marketing emails delivered                           0.610280       0.045292
# Number of Unique Forms Submitted                    -0.117422      -0.062959
# Number of Visits                                    -0.043197      -0.045804
# LinkedIn Clicks                                     -0.002003      -0.020972
# Event Revenue                                             NaN            NaN
# Marketing emails clicked                            -0.033079      -0.189976
# Follower Count                                      -0.024051       0.115001
# Associated Company ID                                0.436277      -0.292273
# Twitter Clicks                                      -0.013871            NaN
# Likelihood to close                                 -0.075436            NaN
# LinkedIn Connections                                 0.193656            NaN
# Sends Since Last Engagement                          1.000000       0.117786
# Days To Close                                        0.117786       1.000000
# Marketing emails bounced                             0.468198            NaN
#
#                                   Marketing emails bounced
# Contact ID                                        0.168144
# Broadcast Clicks                                       NaN
# Marketing emails opened                                NaN
# Total Revenue                                          NaN
# Klout Score                                            NaN
# Number of Pageviews                              -0.012648
# Facebook Clicks                                        NaN
# Associated Deals                                       NaN
# Recent Deal Amount                                     NaN
# Number of times contacted                         0.101079
# Number of Sales Activities                        0.017934
# Number of Form Submissions                       -0.011755
# Number of event completions                            NaN
# Average Pageviews                                -0.013580
# Marketing emails delivered                        0.262781
# Number of Unique Forms Submitted                 -0.011755
# Number of Visits                                 -0.013861
# LinkedIn Clicks                                        NaN
# Event Revenue                                          NaN
# Marketing emails clicked                               NaN
# Follower Count                                         NaN
# Associated Company ID                             0.169879
# Twitter Clicks                                         NaN
# Likelihood to close                              -0.072175
# LinkedIn Connections                                   NaN
# Sends Since Last Engagement                       0.468198
# Days To Close                                          NaN
# Marketing emails bounced                          1.000000
#
# [28 rows x 28 columns]

# %%
df_contacts.describe()
# Out:
#          Contact ID  Broadcast Clicks  Marketing emails opened  Total Revenue  \
# count  1.041700e+04      10417.000000              1828.000000     170.000000
# mean   7.954949e+05          0.000672                 1.336433   13704.405647
# std    7.005237e+05          0.044896                 0.672427   15040.447501
# min    5.100000e+01          0.000000                 1.000000     500.000000
# 25%    8.756500e+04          0.000000                 1.000000    5175.000000
# 50%    6.417510e+05          0.000000                 1.000000    9000.000000
# 75%    1.534560e+06          0.000000                 1.000000   15468.750000
# max    1.983701e+06          4.000000                 3.000000  100920.000000
#
#        Klout Score  Number of Pageviews  Facebook Clicks  Associated Deals  \
# count   327.000000         10417.000000     10417.000000        467.000000
# mean     28.651376             2.197946         0.000768          1.027837
# std      15.377286            62.136791         0.061965          0.188955
# min      10.000000             0.000000         0.000000          1.000000
# 25%      15.000000             0.000000         0.000000          1.000000
# 50%      25.000000             0.000000         0.000000          1.000000
# 75%      41.000000             0.000000         0.000000          1.000000
# max      87.000000          4669.000000         6.000000          3.000000
#
#        Recent Deal Amount  Number of times contacted  \
# count          169.000000                5957.000000
# mean         13209.461302                   4.846903
# std          15059.105761                   5.948294
# min            500.000000                   0.000000
# 25%           4800.000000                   1.000000
# 50%           7800.000000                   3.000000
# 75%          15000.000000                   6.000000
# max         100920.000000                  88.000000
#
#                  ...             Event Revenue  Marketing emails clicked  \
# count            ...                   10417.0                186.000000
# mean             ...                       0.0                  1.043011
# std              ...                       0.0                  0.203429
# min              ...                       0.0                  1.000000
# 25%              ...                       0.0                  1.000000
# 50%              ...                       0.0                  1.000000
# 75%              ...                       0.0                  1.000000
# max              ...                       0.0                  2.000000
#
#        Follower Count  Associated Company ID  Twitter Clicks  \
# count      554.000000           1.006600e+04    10417.000000
# mean      1477.438628           5.455738e+08        0.000192
# std       7572.510510           2.657699e+08        0.019596
# min          0.000000           1.963816e+08        0.000000
# 25%          9.000000           2.703237e+08        0.000000
# 50%         46.000000           5.077567e+08        0.000000
# 75%        404.500000           8.323831e+08        0.000000
# max      95273.000000           9.676485e+08        2.000000
#
#        Likelihood to close  LinkedIn Connections  Sends Since Last Engagement  \
# count          9582.000000            491.000000                  7046.000000
# mean              0.947934              0.511202                     1.168748
# std               1.906497             11.327471                     1.003921
# min               0.040000              0.000000                     0.000000
# 25%               0.330000              0.000000                     1.000000
# 50%               0.490000              0.000000                     1.000000
# 75%               0.850000              0.000000                     1.000000
# max              55.970000            251.000000                    14.000000
#
#        Days To Close  Marketing emails bounced
# count     772.000000                723.000000
# mean      160.099741                  1.056708
# std       209.815914                  0.254257
# min         1.000000                  1.000000
# 25%         1.000000                  1.000000
# 50%        37.500000                  1.000000
# 75%       312.000000                  1.000000
# max       698.000000                  3.000000
#
# [8 rows x 28 columns]
