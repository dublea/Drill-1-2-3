# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats

plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams.update({'font.size': 22})

# %%
hubspot = 'hubspot-customers-2018_08_14.csv'

# %%
df = pd.read_csv(hubspot)

# %%
#view columns
df.head()
# Out:
#    Company ID Last Modified Date  Lead Status  Total Revenue Postal Code  \
# 0   306887437   2018-08-08 09:59          NaN         4380.0       44139
# 1   245594089   2018-08-08 09:59  TS Customer         9000.0       55436
# 2   293057405   2018-08-08 09:59          NaN        30000.0       83340
# 3   422124906   2018-08-08 09:59          NaN         4800.0         NaN
# 4   474021313   2018-08-08 10:01          NaN        11400.0       84062
#
#    Twitter Followers  Company Domain Name Last Touch Converting Campaign  \
# 0                NaN  americanbassusa.com                            NaN
# 1                NaN       bracketron.com                            NaN
# 2                NaN      smithoptics.com                            NaN
# 3                NaN          SkyBell.com                            NaN
# 4                NaN             asea.net                            NaN
#
#   First Touch Converting Campaign Recent Deal Close Date       ...        \
# 0                             NaN       2017-12-29 00:00       ...
# 1                             NaN       2016-06-29 00:00       ...
# 2                             NaN       2017-01-03 00:00       ...
# 3                             NaN       2017-04-30 00:00       ...
# 4                             NaN       2016-05-31 00:00       ...
#
#                                          Description TrackStreet Competitor  \
# 0                  Welcome To American Bass Website!                    NaN
# 1  Bracketron is the industry leader in providing...                    NaN
# 2  Smith Optics sets the standard for high perfor...            MarketTrack
# 3  The SkyBell HD Video Doorbell sends live video...                    NaN
# 4  Welcome to ASEA! ASEA is an emerging global le...                    NaN
#
#    Annual Revenue  Last Salesforce Sync Time Prospect Status  \
# 0       1000000.0                        NaN             NaN
# 1       1000000.0           2016-10-01 12:46             NaN
# 2     500000000.0                        NaN             NaN
# 3       1000000.0                        NaN             NaN
# 4      50000000.0                        NaN             NaN
#
#                        Industry Street Address 2 Is Public     Customer  \
# 0          Consumer Electronics              NaN     False  TrackStreet
# 1          Consumer Electronics              NaN     False  TrackStreet
# 2                Sporting Goods              NaN     False  TrackStreet
# 3          Consumer Electronics              NaN     False  TrackStreet
# 4  Health, Wellness and Fitness        SUITE 100     False  TrackStreet
#
#    Parent Company
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 98 columns]

# %%
#reduce columns
df_v2 = df.loc[:, ('Name', 'Total Revenue', 'Annual Revenue', 'Industry',
             'Number of Employees', 'Company Domain Name', 'Close Date',
             'First Conversion Date', 'Original Source Type', 'Days to Close',
             'Quantity of Contract UPCs', 'Company owner', 'TrackStreet Customer Number',
             'State/Region', 'Postal Code', 'Is Public', 'Company ID')]
df_v2.head( )
# Out:
#                                   Name  Total Revenue  Annual Revenue  \
# 0  American Bass (Five Star Car Audio)         4380.0       1000000.0
# 1                     Bracketron, Inc.         9000.0       1000000.0
# 2                   Smith Optics, Inc.        30000.0     500000000.0
# 3                              SkyBell         4800.0       1000000.0
# 4                                 ASEA        11400.0      50000000.0
#
#                        Industry  Number of Employees  Company Domain Name  \
# 0          Consumer Electronics                 25.0  americanbassusa.com
# 1          Consumer Electronics                 50.0       bracketron.com
# 2                Sporting Goods                500.0      smithoptics.com
# 3          Consumer Electronics                 25.0          SkyBell.com
# 4  Health, Wellness and Fitness               1000.0             asea.net
#
#          Close Date First Conversion Date Original Source Type  Days to Close  \
# 0  2017-12-29 15:19      2018-01-15 11:00      Offline Sources          343.0
# 1  2017-08-09 11:53                   NaN      Offline Sources          311.0
# 2  2017-05-18 14:22                   NaN      Offline Sources          229.0
# 3  2017-04-12 09:08                   NaN      Offline Sources           14.0
# 4  2017-08-09 11:29                   NaN      Offline Sources           68.0
#
#    Quantity of Contract UPCs                     Company owner  \
# 0                        NaN                      Brian Kresin
# 1                       80.0                     Ryan Erickson
# 2                      750.0                     Ryan Erickson
# 3                       10.0  Andrew Schydlowsky (TrackStreet)
# 4                        NaN  Andrew Schydlowsky (TrackStreet)
#
#    TrackStreet Customer Number State/Region Postal Code Is Public  Company ID
# 0                         99.0           OH       44139     False   306887437
# 1                         34.0           MO       55436     False   245594089
# 2                         53.0           ID       83340     False   293057405
# 3                         59.0          NaN         NaN     False   422124906
# 4                         69.0           UT       84062     False   474021313

# %%
tot_rev = np.array(df_v2['Total Revenue'].dropna())

# %%
sns.distplot(tot_rev, kde=False, rug = True)
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(tot_rev, kde=False)
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(tot_rev)
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.kdeplot(tot_rev)

# %%
sns.distplot(tot_rev, rug = True)
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_v2[df_v2['Total Revenue'].isna()]
# Out:
#                                        Name  Total Revenue  Annual Revenue  \
# 20                         Kill Cliff, Inc.            NaN      10000000.0
# 26               Natural Immunogenics Corp.            NaN             NaN
# 55                                  Celsius            NaN      50000000.0
# 81   Sabre (Security Equipment Corporation)            NaN      50000000.0
# 101                           C&A Marketing            NaN     250000000.0
#
#              Industry  Number of Employees Company Domain Name  \
# 20   Food & Beverages                200.0       killcliff.com
# 26                NaN                 50.0         n-icorp.com
# 55                NaN                200.0         celsius.com
# 81    Law Enforcement                200.0        sabrered.com
# 101               NaN               1000.0        caglobal.com
#
#            Close Date First Conversion Date Original Source Type  \
# 20   2018-01-26 10:35                   NaN      Offline Sources
# 26   2017-12-04 17:28                   NaN      Offline Sources
# 55   2018-02-28 14:02                   NaN      Offline Sources
# 81   2017-12-04 15:27      2018-06-29 09:40      Offline Sources
# 101  2017-04-12 09:06      2017-01-19 11:14       Direct Traffic
#
#      Days to Close  Quantity of Contract UPCs  \
# 20           112.0                        NaN
# 26           429.0                        NaN
# 55           124.0                        NaN
# 81           429.0                        NaN
# 101           82.0                       25.0
#
#                         Company owner  TrackStreet Customer Number  \
# 20   Andrew Schydlowsky (TrackStreet)                         92.0
# 26                      Ryan Erickson                         10.0
# 55   Andrew Schydlowsky (TrackStreet)                         91.0
# 81                       Brian Kresin                         19.0
# 101                     Ryan Erickson                         52.0
#
#     State/Region Postal Code Is Public  Company ID
# 20            GA       30324     False   565417290
# 26            FL       34243     False   270324248
# 55            FL       33431      True   587455246
# 81            MO       63026     False   245594169
# 101           NJ       08837     False   340956483

# %%
df_v2.corr()
# Out:
#                              Total Revenue  Annual Revenue  \
# Total Revenue                     1.000000        0.418033
# Annual Revenue                    0.418033        1.000000
# Number of Employees               0.395522        0.648208
# Days to Close                     0.128287        0.033693
# Quantity of Contract UPCs         0.909618        0.294326
# TrackStreet Customer Number      -0.001652        0.060094
# Company ID                       -0.055015        0.046410
#
#                              Number of Employees  Days to Close  \
# Total Revenue                           0.395522       0.128287
# Annual Revenue                          0.648208       0.033693
# Number of Employees                     1.000000       0.054535
# Days to Close                           0.054535       1.000000
# Quantity of Contract UPCs               0.170627       0.105120
# TrackStreet Customer Number             0.003285      -0.241857
# Company ID                             -0.018406      -0.690104
#
#                              Quantity of Contract UPCs  \
# Total Revenue                                 0.909618
# Annual Revenue                                0.294326
# Number of Employees                           0.170627
# Days to Close                                 0.105120
# Quantity of Contract UPCs                     1.000000
# TrackStreet Customer Number                  -0.005808
# Company ID                                   -0.035937
#
#                              TrackStreet Customer Number  Company ID
# Total Revenue                                  -0.001652   -0.055015
# Annual Revenue                                  0.060094    0.046410
# Number of Employees                             0.003285   -0.018406
# Days to Close                                  -0.241857   -0.690104
# Quantity of Contract UPCs                      -0.005808   -0.035937
# TrackStreet Customer Number                     1.000000    0.733503
# Company ID                                      0.733503    1.000000

# %%
# How can I remove outliers?
# Also wish these were a bit interactive, perhaps when hovering the cursor
# over a datapoint, information about the datapoint appears
sns.jointplot(x="Total Revenue", y="Quantity of Contract UPCs", data=df_v2)
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x="Total Revenue", y="Quantity of Contract UPCs", data=df_v2, kind="reg")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x="Total Revenue", y="Quantity of Contract UPCs", data=df_v2, kind="hex")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.countplot(x="Industry", data=df_v2, palette="Blues")
plt.xticks(rotation = 90);

# %%
sns.boxplot(x="Industry", y="Total Revenue", data=df_v2)
plt.xticks(rotation=90);

# %%
sns.violinplot(x="Industry", y="Total Revenue", data=df_v2, inner=None)
plt.xticks(rotation=90);

# %%
sns.stripplot(x="Industry", y="Total Revenue", data=df_v2, jitter=True)
plt.xticks(rotation=90);

# %%
sns.stripplot(x="Industry", y="Total Revenue", data=df_v2)
plt.xticks(rotation=90);

# %%
sns.swarmplot(x="Industry", y="Total Revenue", data=df_v2)
plt.xticks(rotation=90);

# %%
sns.violinplot(x="Industry", y="Total Revenue", data=df_v2, inner=None)
sns.swarmplot(x="Industry", y="Total Revenue", data=df_v2, color="w", alpha=.5)
plt.xticks(rotation = 90);
